# %%
import IPython
import soundfile as sf
import matplotlib.pyplot as plt
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import urllib.request
import io
# %matplotlib inline
import librosa

# %%
url = "https://github.com/DiyeMark/audio_data/blob/194aac500c3e77b9662cbb6d3913db7132e09e2d/tr_10806_tr02129.wav?raw=true"
response = urllib.request.urlopen(url)
data, rate = sf.read(io.BytesIO(response.read()))

# %%
IPython.display.Audio(data=data, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig, ax = plt.subplots(figsize=(20,3))
ax.plot(data)

# %% [markdown]
# ### remove silence

# %%
# audio, sr = librosa.load(data, sr= 8000, mono=True)
clips = librosa.effects.split(data, top_db=10)
wav_data = []
for c in clips:
    audio_data = data[c[0]: c[1]]
    wav_data.extend(audio_data)

# %%
fig, ax = plt.subplots(figsize=(20,3))
ax.plot(wav_data)

# %%
IPython.display.Audio(data=wav_data, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
